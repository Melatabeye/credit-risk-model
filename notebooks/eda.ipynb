# %%
import pandas as pd

df = pd.read_csv("data/raw/your_dataset.csv")

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("data/raw/your_dataset.csv")
#       4
#       5 df.head()
#       6
#
# File c:\Users\HP\Documents\credit-risk-model\venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\HP\Documents\credit-risk-model\venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File c:\Users\HP\Documents\credit-risk-model\venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\HP\Documents\credit-risk-model\venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File c:\Users\HP\Documents\credit-risk-model\venv\Lib\site-packages\pandas\io\common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/raw/your_dataset.csv'

# %%
import kagglehub

path = kagglehub.dataset_download("atwine/xente-challenge")

path

# %%
import kagglehub

path = kagglehub.dataset_download("atwine/xente-challenge")
path
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import kagglehub
#       2
#       3 path = kagglehub.dataset_download("atwine/xente-challenge")
#       4 path
#
# File c:\Users\HP\Documents\credit-risk-model\venv\Lib\site-packages\kagglehub\__init__.py:4
#       1 __version__ = "1.0.1"
#       3 import kagglehub.logger  # configures the library logger.
# ----> 4 from kagglehub import colab_cache_resolver, http_resolver, kaggle_cache_resolver, registry
#       5 from kagglehub.auth import login, whoami
#       6 from kagglehub.competition import competition_download
#
# File c:\Users\HP\Documents\credit-risk-model\venv\Lib\site-packages\kagglehub\colab_cache_resolver.py:5
#       2 import os
#       3 import time
# ----> 5 from kagglehub.clients import ColabClient
#       6 from kagglehub.config import is_colab_cache_disabled
#       7 from kagglehub.exceptions import BackendError, NotFoundError
#
# File c:\Users\HP\Documents\credit-risk-model\venv\Lib\site-packages\kagglehub\clients.py:22
#      19 from tqdm import tqdm
#      21 import kagglehub
# ---> 22 from kagglehub.cache import delete_from_cache, get_cached_archive_path
#      23 from kagglehub.config import get_kaggle_credentials
#      24 from kagglehub.datasets_enums import KaggleDatasetAdapter
#
# File c:\Users\HP\Documents\credit-risk-model\venv\Lib\site-packages\kagglehub\cache.py:6
#       3 from pathlib import Path
#       5 from kagglehub.config import get_cache_folder
# ----> 6 from kagglehub.handle import CompetitionHandle, DatasetHandle, ModelHandle, NotebookHandle, ResourceHandle
#       8 DATASETS_CACHE_SUBFOLDER = "datasets"
#       9 NOTEBOOKS_CACHE_SUBFOLDER = "notebooks"  # for resources under kaggle.com/code
#
# File c:\Users\HP\Documents\credit-risk-model\venv\Lib\site-packages\kagglehub\handle.py:6
#       3 import abc
#       4 from dataclasses import asdict, dataclass
# ----> 6 from kagglesdk.kaggle_env import get_env, get_web_endpoint
#       7 from kagglesdk.models.types.model_enums import ModelFramework
#       9 from kagglehub.enum import to_enum
#
# ImportError: cannot import name 'get_web_endpoint' from 'kagglesdk.kaggle_env' (c:\Users\HP\Documents\credit-risk-model\venv\Lib\site-packages\kagglesdk\kaggle_env.py)
